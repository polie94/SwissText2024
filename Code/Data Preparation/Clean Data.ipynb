# %% [markdown]
# #Clean Data

# %%
import pandas as pd
import csv
import os
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from string import punctuation
import spacy

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Read Document

# %%
def open_document(n):
    with open("/content/drive/MyDrive/Masterthesis_clean/Data/data_unprocessed/combined.tsv", 'r', newline='', encoding='utf-8') as f:
        dialect = csv.Sniffer().sniff(f.read(2048))
        f.seek(0)
        reader = csv.reader(f, dialect)
        header = next(reader)
        combined = pd.DataFrame(reader,columns=["sentiment","text"])
        combined=combined[combined['text'].str.split().apply(len)>10 ]
        combined=combined.sample(n,random_state=123)
        return combined


nltk.download('punkt')
nltk.download('stopwords')

#stemmer = SnowballStemmer("german")
stop_words = set(stopwords.words("german"))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## Cleaning Functions

# %%
def sentiment(label):
    if label =="positive":
        return 1
    elif label =="negative":
        return 0


def preprocess_text_lower_remove_punct_stopwords(text):
    email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
    text = re.sub(email_regex, '', text)

    # lowercase
    text = text.lower()

    # replace url addresses with an empty string
    url_pattern = r'(http[s]?:\/\/(?:www\.)?\S+)|(www\.\S+)'
    text = re.sub(url_pattern, '', text)

    # delete brackets and its content
    contains_brackets = r'\([^)]*\)'
    text = re.sub(contains_brackets, '', text)

    # replace phone numbers
    pattern_tel1 = r'\+49\s*\d{1,4}\s*\d{1,4}[\s-]*\d{1,4}'
    pattern_tel2 = r'\+49\s*\(\d\)\s*\d{4}-\d{2}\s*\d'
    pattern_tel3 = r'\+\d{2}\.\d{3}\.\d{3}\.\d{1,4}'

    # replace website addresses with an empty string
    text = re.sub(pattern_tel1, '', text)
    text = re.sub(pattern_tel2, '', text)
    text = re.sub(pattern_tel3, '', text)

    text = re.sub("ue", 'ü', text)
    text = re.sub("ae", 'ä', text)
    text = re.sub("oe", 'ö', text)
    text = re.sub("Ue", 'Ü', text)
    text = re.sub("Ae", 'Ä', text)
    text = re.sub("Oe", 'Ö', text)

    # from https://gist.github.com/slowkow/7a7f61f495e3dbb7e3d767f97bd7304b#gistcomment-3315605
    emoji_pattern = re.compile(pattern="["
                    u"\U0001F600-\U0001F64F"  # emoticons
                    u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                    u"\U0001F680-\U0001F6FF"  # transport & map symbols
                    u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                    u"\U00002500-\U00002BEF"  # chinese char
                    u"\U00002702-\U000027B0"
                    u"\U00002702-\U000027B0"
                    u"\U000024C2-\U0001F251"
                    u"\U0001f926-\U0001f937"
                    u"\U00010000-\U0010ffff"
                    u"\u2640-\u2642"
                    u"\u2600-\u2B55"
                    u"\u200d"
                    u"\u23cf"
                    u"\u23e9"
                    u"\u231a"
                    u"\ufe0f"  # dingbats
                    u"\u3030"
                "]+", flags = re.UNICODE)

    text = re.sub(emoji_pattern, '', text)
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'"{2,}', '"', text)
    text = text.replace(' .',".")
    text = text.replace(' ,',", ")
    text = text.replace(' !',"!")
    text = text.replace(' ?',"?")
    text = text.replace(' :',":")
    text = text.replace(' ;',";")
    text = ' '.join([word for word in text.split(' ') if word not in stop_words]) #for normal model auskommentieren
    text = re.sub(r'@\S', '', text)
    text= re.sub(r'#\S+', ' ', text)
    text = re.sub('[%s]' % re.escape(punctuation), ' ', text) #for normal model und mit lowecased_wirt_punctuation_and_stopwords auskommentieren
# remove single letters and numbers surrounded by space
    text = re.sub(r'\s[a-z]\s|\s[0-9]\s', ' ', text)

    text = re.sub(r'\s+', ' ', text)

    return text


def preprocess_text_lower(text):
    email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
    text = re.sub(email_regex, '', text)

    # lowercase
    text = text.lower()

    # replace url addresses with an empty string
    url_pattern = r'(http[s]?:\/\/(?:www\.)?\S+)|(www\.\S+)'
    text = re.sub(url_pattern, '', text)

    # delete brackets and its content
    contains_brackets = r'\([^)]*\)'
    text = re.sub(contains_brackets, '', text)

    # replace phone numbers
    pattern_tel1 = r'\+49\s*\d{1,4}\s*\d{1,4}[\s-]*\d{1,4}'
    pattern_tel2 = r'\+49\s*\(\d\)\s*\d{4}-\d{2}\s*\d'
    pattern_tel3 = r'\+\d{2}\.\d{3}\.\d{3}\.\d{1,4}'

    # replace website addresses with an empty string
    text = re.sub(pattern_tel1, '', text)
    text = re.sub(pattern_tel2, '', text)
    text = re.sub(pattern_tel3, '', text)

    text = re.sub("ue", 'ü', text)
    text = re.sub("ae", 'ä', text)
    text = re.sub("oe", 'ö', text)
    text = re.sub("Ue", 'Ü', text)
    text = re.sub("Ae", 'Ä', text)
    text = re.sub("Oe", 'Ö', text)

    # from https://gist.github.com/slowkow/7a7f61f495e3dbb7e3d767f97bd7304b#gistcomment-3315605
    emoji_pattern = re.compile(pattern="["
                    u"\U0001F600-\U0001F64F"  # emoticons
                    u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                    u"\U0001F680-\U0001F6FF"  # transport & map symbols
                    u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                    u"\U00002500-\U00002BEF"  # chinese char
                    u"\U00002702-\U000027B0"
                    u"\U00002702-\U000027B0"
                    u"\U000024C2-\U0001F251"
                    u"\U0001f926-\U0001f937"
                    u"\U00010000-\U0010ffff"
                    u"\u2640-\u2642"
                    u"\u2600-\u2B55"
                    u"\u200d"
                    u"\u23cf"
                    u"\u23e9"
                    u"\u231a"
                    u"\ufe0f"  # dingbats
                    u"\u3030"
                "]+", flags = re.UNICODE)

    text = re.sub(emoji_pattern, '', text)
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'"{2,}', '"', text)
    text = text.replace(' .',".")
    text = text.replace(' ,',", ")
    text = text.replace(' !',"!")
    text = text.replace(' ?',"?")
    text = text.replace(' :',":")
    text = text.replace(' ;',";")
    text = re.sub(r'@\S', '', text)
    text= re.sub(r'#\S+', ' ', text)
# remove single letters and numbers surrounded by space
    text = re.sub(r'\s[a-z]\s|\s[0-9]\s', ' ', text)
    text = re.sub(r'\s+', ' ', text)

    return text


def preprocess_text_no_lower_with_punct_stop(text):
    email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
    text = re.sub(email_regex, '', text)


    # replace url addresses with an empty string
    url_pattern = r'(http[s]?:\/\/(?:www\.)?\S+)|(www\.\S+)'
    text = re.sub(url_pattern, '', text)

    # delete brackets and its content
    contains_brackets = r'\([^)]*\)'
    text = re.sub(contains_brackets, '', text)

    # replace phone numbers
    pattern_tel1 = r'\+49\s*\d{1,4}\s*\d{1,4}[\s-]*\d{1,4}'
    pattern_tel2 = r'\+49\s*\(\d\)\s*\d{4}-\d{2}\s*\d'
    pattern_tel3 = r'\+\d{2}\.\d{3}\.\d{3}\.\d{1,4}'

    # replace website addresses with an empty string
    text = re.sub(pattern_tel1, '', text)
    text = re.sub(pattern_tel2, '', text)
    text = re.sub(pattern_tel3, '', text)

    text = re.sub("ue", 'ü', text)
    text = re.sub("ae", 'ä', text)
    text = re.sub("oe", 'ö', text)
    text = re.sub("Ue", 'Ü', text)
    text = re.sub("Ae", 'Ä', text)
    text = re.sub("Oe", 'Ö', text)

    # from https://gist.github.com/slowkow/7a7f61f495e3dbb7e3d767f97bd7304b#gistcomment-3315605
    emoji_pattern = re.compile(pattern="["
                    u"\U0001F600-\U0001F64F"  # emoticons
                    u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                    u"\U0001F680-\U0001F6FF"  # transport & map symbols
                    u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                    u"\U00002500-\U00002BEF"  # chinese char
                    u"\U00002702-\U000027B0"
                    u"\U00002702-\U000027B0"
                    u"\U000024C2-\U0001F251"
                    u"\U0001f926-\U0001f937"
                    u"\U00010000-\U0010ffff"
                    u"\u2640-\u2642"
                    u"\u2600-\u2B55"
                    u"\u200d"
                    u"\u23cf"
                    u"\u23e9"
                    u"\u231a"
                    u"\ufe0f"  # dingbats
                    u"\u3030"
                "]+", flags = re.UNICODE)

    text = re.sub(emoji_pattern, '', text)
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'"{2,}', '"', text)
    text = text.replace(' .',".")
    text = text.replace(' ,',", ")
    text = text.replace(' !',"!")
    text = text.replace(' ?',"?")
    text = text.replace(' :',":")
    text = text.replace(' ;',";")
    text = re.sub(r'@\S', '', text)
    text= re.sub(r'#\S+', ' ', text)
# remove single letters and numbers surrounded by space
    text = re.sub(r'\s[a-z]\s|\s[0-9]\s', ' ', text)

    text = re.sub(r'\s+', ' ', text)

    return text

# %% [markdown]
# ### DO remove Stopwords, Punctuation & DO Lowercasing

# %%
combined=open_document(50000)
combined['preprocessed_text'] = combined['text'].apply(preprocess_text_lower_remove_punct_stopwords)
combined['sentiment'] = combined['sentiment'].apply(lambda x: sentiment(x))
output_path = "/content/drive/MyDrive/Masterthesis/Data/data_processed/preprocessed50000_lower_with_removed_punctuation_and_stopwords.tsv"
combined.to_csv(output_path, sep='\t', index=False)

# %% [markdown]
# ## DO NOT remove Stopwords, Punctuation & DO Lowercasing

# %%
combined=open_document(50000)
combined['preprocessed_text'] = combined['text'].apply(preprocess_text_lower)
combined['sentiment'] = combined['sentiment'].apply(lambda x: sentiment(x))
output_path = "/content/drive/MyDrive/Masterthesis/Data/data_processed/preprocessed50000_lower.tsv"
combined.to_csv(output_path, sep='\t', index=False)

# %% [markdown]
# ## DO NOT remove Stopwords, Punctuation & DO NOT Lowercasing

# %%
combined=open_document(50000)
combined['preprocessed_text'] = combined['text'].apply(preprocess_text_no_lower_with_punct_stop)
combined['sentiment'] = combined['sentiment'].apply(lambda x: sentiment(x))
output_path = "/content/drive/MyDrive/Masterthesis/Data/data_processed/preprocessed50000_no_lower_with_punct_stop1.tsv"
combined.to_csv(output_path, sep='\t', index=False)
